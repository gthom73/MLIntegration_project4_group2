# %% [markdown]
# <a href="https://colab.research.google.com/github/gthom73/MLIntegration_project4_group2/blob/main/Project_4A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Cell 1
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from google.colab import files
import os

# Upload and configure the Kaggle API key
uploaded = files.upload()  # Prompt to upload the kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Install Kaggle API and download the dataset
# !pip install kaggle
# !kaggle datasets download -d ahmedshahriarsakib/usa-real-estate-dataset

# Unzip the dataset with overwrite all option
# !unzip -o usa-real-estate-dataset.zip

# If needed, rename the file automatically
correct_file_name = 'realtor-data.csv'
extracted_file_name = 'realtor-data.zip.csv'

# Check if the extracted file is in the directory with a different name
if extracted_file_name in os.listdir('.'):
    os.rename(extracted_file_name, correct_file_name)

# Load the dataset and print the first 5 rows
if correct_file_name in os.listdir('.'):
    df = pd.read_csv(correct_file_name)
    print(df.head(5))  # Print the first 5 rows of the dataframe
else:
    print(f"File {correct_file_name} not found in the directory.")
# Out:
#      <input type="file" id="files-b6587f5f-006d-4498-863a-6777b2aec126" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b6587f5f-006d-4498-863a-6777b2aec126">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Cell 2
# List of cities to filter by
cities = ['Kansas City', 'Topeka', 'Denver', 'Dallas']

# Dictionary to map cities to their respective states (Kansas City can be in Missouri or Kansas)
city_states = {
    'Kansas City': ['Missouri', 'Kansas'],  # Kansas City can be in Missouri or Kansas
    'Topeka': ['Kansas'],
    'Denver': ['Colorado'],
    'Dallas': ['Texas']
}

# Loop through each city and display the first 5 rows for that city in the correct state(s)
for city, states in city_states.items():
    # Filter the DataFrame for the city and check if it's in one of the correct states
    filtered_df = df[(df['city'] == city) & (df['state'].isin(states))]

    # Check if the filtered dataframe is empty
    if not filtered_df.empty:
        print(f"First 5 rows for {city}, States: {', '.join(states)}:")
        print(filtered_df.head(5))
    else:
        print(f"No data available for {city} in {', '.join(states)}")
# Out:
# First 5 rows for Kansas City, States: Missouri, Kansas:
#         brokered_by    status     price  bed  bath  acre_lot     street  \
# 914988        322.0  for_sale  372000.0  4.0   3.0      0.19  1614471.0
# 914989      58270.0  for_sale   25000.0  3.0   2.0      0.35   144563.0
# 914990      84610.0  for_sale   69950.0  2.0   1.0      0.19  1648065.0
# 914994      33478.0  for_sale  109000.0  2.0   3.0      0.07  1747899.0
# 915001      20177.0  for_sale  137500.0  4.0   1.0      0.23  1740406.0
#
#                city     state  zip_code  house_size prev_sold_date
# 914988  Kansas City  Missouri   64158.0      2300.0     2016-09-09
# 914989  Kansas City  Missouri   64133.0      1884.0     2004-03-22
# 914990  Kansas City  Missouri   64129.0      1134.0            NaN
# 914994  Kansas City  Missouri   64134.0      2062.0     2005-01-13
# 915001  Kansas City  Missouri   64134.0       912.0     2008-02-06
# First 5 rows for Topeka, States: Kansas:
# ...

# %%
# Cell 3
# List of cities to analyze
cities = ['Kansas City', 'Topeka', 'Denver', 'Dallas']

# Filter the DataFrame for these cities
filtered_df = df[df['city'].isin(cities)]

# Group by city and number of bedrooms, then calculate count and mean price
result = filtered_df.groupby(['city', 'bed']).agg(
    Houses_Available=('price', 'count'),
    Average_Price=('price', 'mean')
).reset_index()

# Format the Average Price to be more readable
result['Average_Price'] = result['Average_Price'].round(2)

print(result)
# Out:
#            city    bed  Houses_Available  Average_Price
# 0        Dallas    1.0               413      228606.82
# 1        Dallas    2.0              1588      399111.65
# 2        Dallas    3.0              3399      474756.44
# 3        Dallas    4.0              1938      698018.75
# 4        Dallas    5.0               483     1382225.59
# 5        Dallas    6.0                86     2103946.91
# 6        Dallas    7.0                10     5322690.00
# 7        Dallas    8.0                16     2841325.00
# 8        Dallas    9.0                 2     8525000.00
# 9        Dallas   10.0                 1     1597500.00
# 10       Dallas   14.0                 2     1029500.00
# 11       Dallas   23.0                 1      680000.00
# 12       Dallas   28.0                 1     3975000.00
# 13       Dallas   62.0                 1     6500000.00
# 14       Dallas  222.0                 1      699000.00
# 15       Denver    1.0               277      442537.16
# ...

# %%
# Cell 4
# List of cities to analyze and their acceptable states
city_states = {
    'Kansas City': ['Missouri', 'Kansas'],  # Kansas City can be in Missouri or Kansas
    'Topeka': ['Kansas'],
    'Denver': ['Colorado'],
    'Dallas': ['Texas']
}

# Convert city_states dictionary to a DataFrame for easier filtering
cities_df = pd.DataFrame([(city, state) for city, states in city_states.items() for state in states], columns=['city', 'state'])

# Merge the cities DataFrame with the main DataFrame to filter correctly by city and state
filtered_df = pd.merge(df, cities_df, on=['city', 'state'])

# Further filter the DataFrame to ensure the number of bedrooms is 5 or less
filtered_df = filtered_df[filtered_df['bed'] <= 5]

# Group by city, state, and number of bedrooms ('bed'), then calculate count and mean price
result = filtered_df.groupby(['city', 'state', 'bed']).agg(
    Houses_Available=('price', 'count'),
    Average_Price=('price', 'mean')
).reset_index()

# Format the Average Price to be more readable
result['Average_Price'] = result['Average_Price'].round(2)

# Display the results
print(result)
# Out:
#            city     state  bed  Houses_Available  Average_Price
# 0        Dallas     Texas  1.0               411      229210.99
# 1        Dallas     Texas  2.0              1518      404114.66
# 2        Dallas     Texas  3.0              2964      490675.12
# 3        Dallas     Texas  4.0              1625      756389.96
# 4        Dallas     Texas  5.0               368     1664239.68
# 5        Denver  Colorado  1.0               276      441501.78
# 6        Denver  Colorado  2.0               675      573979.85
# 7        Denver  Colorado  3.0               663      705512.41
# 8        Denver  Colorado  4.0               454      979627.41
# 9        Denver  Colorado  5.0               172     1611204.88
# 10  Kansas City    Kansas  1.0                 2      152500.00
# 11  Kansas City    Kansas  2.0                79      171958.86
# 12  Kansas City    Kansas  3.0               149      211580.23
# 13  Kansas City    Kansas  4.0                66      478251.41
# ...

# %%
# Cell 5
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a new column 'City_State' combining city and state for clearer labeling in the graph
result['City_State'] = result['city'] + ', ' + result['state']

# Create a line plot
plt.figure(figsize=(12, 8))
lineplot = sns.lineplot(data=result, x='bed', y='Average_Price', hue='City_State', marker='o')

# Adding titles and labels
plt.title('Average Price vs. Number of Bedrooms for Each City and State', fontsize=16)
plt.xlabel('Number of Bedrooms', fontsize=14)
plt.ylabel('Average Price', fontsize=14)
plt.xticks(result['bed'].unique())  # Ensure all bedroom categories are shown

# Format the y-axis to show dollar sign and the value
lineplot.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'${int(x/1000)}k'))

# Enhance the legend for better clarity
plt.legend(title='City, State')
plt.show()

# %%
# Cell 6
import pandas as pd

# List of cities to analyze and their acceptable states
city_states = {
    'Kansas City': ['Missouri', 'Kansas'],  # Kansas City can be in Missouri or Kansas
    'Topeka': ['Kansas'],
    'Denver': ['Colorado'],
    'Dallas': ['Texas']
}

# Convert city_states dictionary to a DataFrame for easier filtering
cities_df = pd.DataFrame([(city, state) for city, states in city_states.items() for state in states], columns=['city', 'state'])

# Merge the cities DataFrame with the main DataFrame to filter correctly by city and state
filtered_df = pd.merge(df, cities_df, on=['city', 'state'])

# Further filter the DataFrame to ensure the number of bedrooms is 2, 3, or 4
filtered_df = filtered_df[filtered_df['bed'].isin([2, 3, 4])]

# Group by city, state, and number of bedrooms ('bed'), then calculate count and mean price
result = filtered_df.groupby(['city', 'state', 'bed']).agg(
    Houses_Available=('price', 'count'),
    Average_Price=('price', 'mean')
).reset_index()

# Format the Average Price to be more readable
result['Average_Price'] = result['Average_Price'].round(2)

# Print result to verify
print(result)
# Out:
#            city     state  bed  Houses_Available  Average_Price
# 0        Dallas     Texas  2.0              1518      404114.66
# 1        Dallas     Texas  3.0              2964      490675.12
# 2        Dallas     Texas  4.0              1625      756389.96
# 3        Denver  Colorado  2.0               675      573979.85
# 4        Denver  Colorado  3.0               663      705512.41
# 5        Denver  Colorado  4.0               454      979627.41
# 6   Kansas City    Kansas  2.0                79      171958.86
# 7   Kansas City    Kansas  3.0               149      211580.23
# 8   Kansas City    Kansas  4.0                66      478251.41
# 9   Kansas City  Missouri  2.0               308      235661.19
# 10  Kansas City  Missouri  3.0               737      284383.76
# 11  Kansas City  Missouri  4.0               609      490832.66
# 12       Topeka    Kansas  2.0                92      104748.36
# 13       Topeka    Kansas  3.0               244      169137.67
# ...

# %%
# Cell 7
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a new column 'City_State' combining city and state for clearer labeling in the graph
result['City_State'] = result['city'] + ', ' + result['state']

# Create a single line plot
plt.figure(figsize=(12, 8))
lineplot = sns.lineplot(data=result, x='bed', y='Average_Price', hue='City_State', style='City_State', markers=True, dashes=False)

# Adding titles and labels
plt.title('Average Price vs. Number of Bedrooms Across Cities and States', fontsize=16)
plt.xlabel('Number of Bedrooms', fontsize=14)
plt.ylabel('Average Price', fontsize=14)
plt.xticks([2, 3, 4])  # Ensure ticks for 2, 3, and 4 bedrooms are shown

# Format the y-axis to show dollar sign and the value
lineplot.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'${int(x/1000)}k'))

# Enhance the legend for better clarity
plt.legend(title='City, State', loc='upper left')

plt.show()

# %%
# Cell 8
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Continue using the filtered_df from your previous steps if it's already filtered by city and state
# If not, reapply the city and state filters
city_states = {
    'Kansas City': ['Missouri', 'Kansas'],  # Kansas City can be in Missouri or Kansas
    'Topeka': ['Kansas'],
    'Denver': ['Colorado'],
    'Dallas': ['Texas']
}

# Create a DataFrame for easier filtering by city and state
cities_df = pd.DataFrame([(city, state) for city, states in city_states.items() for state in states], columns=['city', 'state'])

# Merge with the main DataFrame
filtered_df = pd.merge(df, cities_df, on=['city', 'state'])

# Calculate average price per zip code within each city
zip_code_averages = filtered_df.groupby(['city', 'state', 'zip_code']).agg(Average_Price=('price', 'mean')).reset_index()
zip_code_averages['Average_Price'] = zip_code_averages['Average_Price'].round(2)

# Display the results
print(zip_code_averages.head())
# Out:
#      city  state  zip_code  Average_Price
# 0  Dallas  Texas   75051.0      294857.14
# 1  Dallas  Texas   75201.0     2087708.99
# 2  Dallas  Texas   75202.0      344149.98
# 3  Dallas  Texas   75203.0      383505.73
# 4  Dallas  Texas   75204.0      592935.40

# %%
# Cell 9
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.cm as cm

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Determine global price range for consistent color mapping across all plots, adjusted for thousands
global_min = zip_code_averages['Average_Price'].min() / 1000
global_max = zip_code_averages['Average_Price'].max() / 1000

# Create a single column of plots with increased width for better readability
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(18, 24))

# Define a colormap
cmap = sns.color_palette("viridis", as_cmap=True)

cities = ['Kansas City', 'Topeka', 'Denver', 'Dallas']
for ax, city in zip(axes, cities):
    # Filter the data for each city
    city_data = zip_code_averages[zip_code_averages['city'] == city]
    city_data = city_data.sort_values(by='Average_Price', ascending=False)

    # Calculate the city-wide average price for the horizontal line, adjusted for thousands
    city_avg_price = city_data['Average_Price'].mean() / 1000

    # Normalize the average price for color mapping across all data, adjusted for thousands
    norm = plt.Normalize(global_min, global_max)

    # Create the bar plot with price divided by 1000 for scale adjustment
    bars = sns.barplot(x='zip_code', y=city_data['Average_Price'] / 1000, data=city_data, ax=ax,
                       palette=cmap(norm(city_data['Average_Price'] / 1000)))

    # Draw a horizontal line for the city-wide average price
    ax.axhline(y=city_avg_price, color='red', linestyle='--', label=f'City Avg: ${city_avg_price:.2f}k')

    # Set plot details
    ax.set_title(f'Average Sale Price by Zip Code in {city}')
    ax.set_xlabel('Zip Code')
    ax.set_ylabel('Average Price ($, thousands)')
    ax.tick_params(axis='x', rotation=90, labelsize=10)  # Rotate to vertical for better legibility

    # Add legend to show what the line represents
    ax.legend()

    # Create a colorbar with more detailed description
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=ax, orientation='vertical', fraction=0.02, pad=0.05)
    cbar.set_label('Average Sale Price ($, thousands)', size=12)
    cbar.ax.tick_params(labelsize=10)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-9-4de6b5fb7480>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(x='zip_code', y=city_data['Average_Price'] / 1000, data=city_data, ax=ax,
# <ipython-input-9-4de6b5fb7480>:33: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   bars = sns.barplot(x='zip_code', y=city_data['Average_Price'] / 1000, data=city_data, ax=ax,
# <ipython-input-9-4de6b5fb7480>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(x='zip_code', y=city_data['Average_Price'] / 1000, data=city_data, ax=ax,
# ...

# %%
# Cell 10
# Convert city_states dictionary to a DataFrame for easier filtering
cities_df = pd.DataFrame([(city, state) for city, states in city_states.items() for state in states], columns=['city', 'state'])

# Merge the cities DataFrame with the main DataFrame to filter correctly by city and state
filtered_df = pd.merge(df, cities_df, on=['city', 'state'])

# Calculate dollars per square foot using 'house_size'
filtered_df['price_per_sqft'] = filtered_df['price'] / filtered_df['house_size']

# Group by zip code within the filtered data and calculate the average price per square foot
zip_code_stats = filtered_df.groupby('zip_code').agg(
    average_price_per_sqft=('price_per_sqft', 'mean')
).reset_index()

# Format the average price per square foot for better readability
zip_code_stats['average_price_per_sqft'] = zip_code_stats['average_price_per_sqft'].round(2)

# Display the results
print(zip_code_stats.head())
# Out:
#    zip_code  average_price_per_sqft
# 0   64079.0                     NaN
# 1   64105.0                  218.31
# 2   64106.0                  238.58
# 3   64108.0                  258.73
# 4   64109.0                  143.85

# %%
# Cell 11
# Group by zip code within the filtered data and calculate the average price per square foot
zip_code_stats = filtered_df.groupby('zip_code').agg(
    average_price_per_sqft=('price_per_sqft', 'mean')
).reset_index()

# Format the average price per square foot for better readability
zip_code_stats['average_price_per_sqft'] = zip_code_stats['average_price_per_sqft'].round(2)

# Display the results
print(zip_code_stats.head())
# Out:
#    zip_code  average_price_per_sqft
# 0   64079.0                     NaN
# 1   64105.0                  218.31
# 2   64106.0                  238.58
# 3   64108.0                  258.73
# 4   64109.0                  143.85

# %%
# Cell 12
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Iterate over each city and its corresponding states and create a line plot
for city, states in city_states.items():
    # Filter data for the current city and its states
    city_data = filtered_df[(filtered_df['city'] == city) & (filtered_df['state'].isin(states))]

    # Create the line plot
    plt.figure(figsize=(12, 8))
    lineplot = sns.lineplot(data=city_data, x='house_size', y='price_per_sqft', marker='o', label=city)

    # Adding titles and labels
    plt.title(f'Price per Square Foot by House Size in {city}', fontsize=16)
    plt.xlabel('House Size (house_size)', fontsize=14)
    plt.ylabel('Price per Square Foot ($)', fontsize=14)

    # Format the y-axis to show dollar sign and the value
    lineplot.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'${int(x)}'))

    plt.legend(title='City')
    plt.show()

# %%
# Cell 13
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Iterate over each city and create a plot
for city, states in city_states.items():
    # Filter the DataFrame for the current city and its relevant state(s)
    city_data = filtered_df[(filtered_df['city'] == city) & (filtered_df['state'].isin(states))]

    # Group by zip code and calculate the average price per square foot
    city_stats = city_data.groupby('zip_code').agg(
        average_price_per_sqft=('price_per_sqft', 'mean')
    ).reset_index()

    # Calculate the city-wide average price per square foot for the horizontal line
    city_avg_price_per_sqft = city_stats['average_price_per_sqft'].mean()

    # Format the average price per square foot for better readability
    city_stats['average_price_per_sqft'] = city_stats['average_price_per_sqft'].round(2)

    # Create a bar plot for the current city with adjusted figure size and bar width
    plt.figure(figsize=(14, 8))  # Adjusted figure size for better spread
    barplot = sns.barplot(x='zip_code', y='average_price_per_sqft', data=city_stats, palette='coolwarm')
    plt.title(f'Average Price per Square Foot by Zip Code in {city}', fontsize=16)
    plt.xlabel('Zip Code', fontsize=14)
    plt.ylabel('Average Price per Square Foot ($)', fontsize=14)
    plt.xticks(rotation=90)  # Rotate x-axis labels to vertical for maximum readability

    # Format the y-axis to show dollar sign and the value
    barplot.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'${int(x)}'))

    # Draw a horizontal line for the city-wide average price per square foot
    plt.axhline(y=city_avg_price_per_sqft, color='red', linestyle='--', label=f'City Avg: ${city_avg_price_per_sqft:.2f}')
    plt.legend()

    plt.show()
# Out:
# <ipython-input-13-6fd2204b7180>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x='zip_code', y='average_price_per_sqft', data=city_stats, palette='coolwarm')
# <ipython-input-13-6fd2204b7180>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x='zip_code', y='average_price_per_sqft', data=city_stats, palette='coolwarm')
# <ipython-input-13-6fd2204b7180>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x='zip_code', y='average_price_per_sqft', data=city_stats, palette='coolwarm')
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# City-state mapping as defined earlier
city_states = {
    'Kansas City': ['Missouri', 'Kansas'],
    'Topeka': ['Kansas'],
    'Denver': ['Colorado'],
    'Dallas': ['Texas']
}

# Filter the DataFrame for the specified cities and states, and limit to 2, 3, and 4 bedroom homes
filtered_df = df[(df['city'].isin(city_states.keys())) & (df['bed'].isin([2, 3, 4]))]
filtered_df = filtered_df[filtered_df.apply(lambda x: x['state'] in city_states[x['city']], axis=1)]

# Calculate dollars per square foot for the filtered DataFrame
filtered_df['price_per_sqft'] = filtered_df['price'] / filtered_df['house_size']

# Iterate over each city and its corresponding states and create a line plot
for city, states in city_states.items():
    # Filter data for the current city and its states
    city_data = filtered_df[(filtered_df['city'] == city) & (filtered_df['state'].isin(states))]

    # Create the line plot
    plt.figure(figsize=(12, 8))
    lineplot = sns.lineplot(data=city_data, x='house_size', y='price_per_sqft', marker='o', label=city)

    # Adding titles and labels
    plt.title(f'Price per Square Foot by House Size in {city}', fontsize=16)
    plt.xlabel('House Size (sqft)', fontsize=14)
    plt.ylabel('Price per Square Foot ($)', fontsize=14)

    # Format the y-axis to show dollar sign and the value
    lineplot.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'${int(x)}'))

    plt.legend(title='City')
    plt.show()
# Out:
# <ipython-input-15-8b31adef1551>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['price_per_sqft'] = filtered_df['price'] / filtered_df['house_size']

# %% [markdown]
# ## Compile, Train and Evaluate the Model
